# %% [markdown]
# # TransformerGAN
#
# An implementation of text GAN which uses BERT sequence classifier as the discriminator and OpenAI's GPT-2 as the generator

# %%
import os, datetime
import sys
import torch
import random
import argparse
import numpy as np
from gpt2Pytorch.GPT2.model import GPT2LMHeadModel
from gpt2Pytorch.GPT2.utils import load_weight
from gpt2Pytorch.GPT2.config import GPT2Config
from gpt2Pytorch.GPT2.sample import sample_sequence
from gpt2Pytorch.GPT2.encoder import get_encoder
from pytorch_pretrained_bert import GPT2Tokenizer
from torch import nn
from pytorch_pretrained_bert import BertTokenizer, BertForSequenceClassification, BertAdam, OpenAIAdam
import pandas as pd
from datetime import datetime
from torch.nn import functional as F
from pandas import Series, DataFrame
import re

# %%
torch.__version__ # should be 1.4.0
# Out:
# '1.4.0'

# %%
class TrtansformerGAN(object):
    def __init__(self, dataframe, bert_tokenizer, bert_classifier, gpt_tokenizer, gpt_generator, num_labels):
        self.dataframe = dataframe
        self.device_default = device
        
        # Build discriminator and tokenizer from BertForSequenceClassification
        self.bert_tokenizer = bert_tokenizer
        self.discriminator = nn.DataParallel(bert_classifier).to(self.device_default)
        self.bert_optimizer = BertAdam(self.discriminator.parameters(), lr = 0.00005, warmup = 0.1, t_total = 1000)
        
        # Build the generator, tokenizer, optimizer from OpenAIGPT2
        self.gpt2_tokenizer = gpt_tokenizer
        self.generator = gpt_generator.to(self.device_default)
        self.gpt2_optimizer = OpenAIAdam(self.generator.parameters(), lr = 0.0001, warmup = 0.1, t_total = 1000)
        
        # Free all GPU memory
        torch.cuda.empty_cache()

    def textGeneration(self, generator_input):
        text_id = generator_input
        input, past = torch.tensor([text_id]).to(self.device_default), None
        for _ in range(random.randint(30, 100)):
            logits, past = self.generator(input, past = past)
            input = torch.multinomial(F.softmax(logits[:, -1]), 1)
            text_id.append(input.item())
        return self.gpt2_tokenizer.decode(text_id)
    
    def dataGenerator(self, batch_size = 16):
        # Randomly fetch traning data bunch
        sample_text_ss = self.dataframe['original_text'].iloc[random.sample(range(len(self.dataframe)), batch_size)]
        sample_adv_text= self.dataframe['perturbed_text'].iloc[random.sample(range(len(self.dataframe)), batch_size)]
        
        # Tokenize training data bunch with GPT2 tokenizer and take top 10 words
        sample_text_encode_top10 = sample_text_ss.map(lambda x : self.gpt2_tokenizer.encode(x)[:10])
        
        # Generate text using GPT2 generator
        sample_text_generate_ss = sample_text_encode_top10.map(self.textGeneration)
        return sample_text_generate_ss, sample_adv_text
    
    def discriminatorInput(self, text):
        input_token = ['[CLS]'] + self.bert_tokenizer.tokenize(text) + ['[SEP]']
        input_id = self.bert_tokenizer.convert_tokens_to_ids(input_token)
        return [input_id]
    
    def saveGeneratedText(self):
        content = self.dataframe['original_text'].values[random.randint(0, len(self.dataframe))]
        content_id = self.gpt2_tokenizer.encode(content)[:10]
        gen_content = self.textGeneration(content_id)
        gen_content.strip()
        return gen_content, content
    
    def saveCheckpoint(self, state, model_type, epoch):
        if model_type == 'generator':
            filename='GeneratorCheckpoint_Epoch%s'%epoch
        else:
            filename='DiscriminatorCheckpoint_Epoch%s'%epoch
        torch.save(state,filename)
        
    def train(self, num_epochs = 2000, save_interval = 100):
        start = datetime.now()
        generated_text_list = []
        real_text_list = []
        d_loss_list = []
        g_loss_list = []

        for epoch in range(num_epochs):
            try:
                print('Epoch {}/{}'.format(epoch + 1, num_epochs))
                print('-' * 10)

                # Load in data
                sample_text_generate_ss, sample_text_ss = self.dataGenerator(batch_size = 16)
                assert len(sample_text_generate_ss) == len(sample_text_ss)

                # Convert generated text and real text bunch to WorkPiece encode ID as discriminator input
                discriminator_input_ss = pd.concat([sample_text_generate_ss, sample_text_ss], axis = 0, ignore_index = True).map(self.discriminatorInput)
                discriminator_input = torch.LongTensor(np.array(DataFrame(discriminator_input_ss.sum()).fillna(0).astype('int32'))).to(self.device_default)
                discriminator_input_generate = discriminator_input[:len(sample_text_generate_ss)].to(self.device_default)

                # Create labels for training discriminator and generator
                labels = torch.LongTensor([0] * len(sample_text_generate_ss) + [1] * len(sample_text_ss)).to(self.device_default)
                valid = torch.LongTensor([1] * len(sample_text_generate_ss)).to(self.device_default)

                # Each epoch has a train_discriminator and train_generator phase
                for phase in ['train_discriminator', 'train_generator']:
                    if phase == 'train_discriminator':
                        # Set discriminator to training mode
                        self.discriminator.train()

                        # Freeze all trainable parameters
                        for param in self.discriminator.parameters():
                            param.requires_grad = True

                        # Zero the discriminator parameter gradients
                        self.bert_optimizer.zero_grad()

                        # Forward propagation
                        d_loss = self.discriminator(input_ids = discriminator_input, labels = labels).mean()

                        # Backward propagation
                        d_loss.backward()
                        self.bert_optimizer.step()

                    else:
                        # Set discriminator to evaluate mode
                        self.discriminator.eval()

                        # Zero the generator parameter gradients
                        self.gpt2_optimizer.zero_grad()

                        # Forward propagation
                        g_loss = self.discriminator(input_ids = discriminator_input_generate, labels = valid).mean()

                        # Backward propagation
                        g_loss.backward()
                        self.gpt2_optimizer.step()                    

                # Plot the progress
                print('Discriminator Loss:', d_loss)
                print('Generator Loss:', g_loss)
                print()
                d_loss_list.append(d_loss)
                g_loss_list.append(g_loss)

                # If at save interval, then save generated text samples
                if epoch % save_interval == 0:
                    generated_text, real_text = self.saveGeneratedText()
                    
                    file_object = open('gen_textlog.txt', 'a')
                    file_object.write(generated_text)
                    file_object.write('\n----------------------------------------------------------\n')
                    file_object.close()
                    
                    generator_state = {'epoch':epoch, 'state_dict':self.generator.state_dict()}
                    discriminator_state = {'epoch':epoch, 'state_dict':self.discriminator.state_dict()}
                    self.saveCheckpoint(generator_state,'generator',epoch)
                    self.saveCheckpoint(discriminator_state, 'discriminator',epoch)
                    
                    # generated_text_list.append(generated_text)
                    # real_text_list.append(real_text)
            except RuntimeError:
                raise

        # Counting time elapsed
        time_delta = datetime.now() - start
        print('Training completed time:', time_delta)

        return self.generator, self.discriminator, d_loss_list, g_loss_list, generated_text_list, real_text_list

# %%
def cleanText(list_of_texts):
    new_texts=[]
    for text in list_of_texts:
        cleaned_texts=[]
        bracketed_texts=re.findall(r'\[.*?\]', text)
        for item in bracketed_texts:
            first_filter=list(filter(('[').__ne__, item))
            second_filter=list(filter((']').__ne__, first_filter))
            cleaned_texts.append(''.join(second_filter))
        listOfTuples=[]
        for i,clean_text in enumerate(cleaned_texts):
            theTuple=(bracketed_texts[i]+']', clean_text)
            listOfTuples.append(theTuple)
        for r in tuple(listOfTuples):
            text = text.replace(*r)
        text = text.replace('[', '')
        text = text.replace(']', '')
        new_texts.append(text)
    return new_texts

# %%
bert_pretrained_model_path = 'bertPytorch/bert-base-cased'
gpt2_model_path = 'gpt2Pytorch/gpt2-pytorch_model.bin'
gpt2_vocab_path = 'gpt2Pytorch/GPT2-vocab'
assert os.path.exists(bert_pretrained_model_path)
assert os.path.exists(gpt2_model_path)
assert os.path.exists(gpt2_vocab_path)

# %%
num_labels = 2
device = torch.device('cuda:0')

bert_tokenizer = BertTokenizer.from_pretrained(bert_pretrained_model_path)
bert_for_seq_classification = BertForSequenceClassification.from_pretrained(bert_pretrained_model_path, num_labels = num_labels)

gpt2_tokenizer = GPT2Tokenizer.from_pretrained(gpt2_vocab_path)
state_dict = torch.load(gpt2_model_path, map_location='cpu' if not torch.cuda.is_available() else None)
enc = get_encoder()
config = GPT2Config()
gpt2_model = GPT2LMHeadModel(config)
gpt2_model = load_weight(gpt2_model, state_dict)
gpt2_model.to(device)
_ = gpt2_model.eval()

# %%
df = pd.read_csv('textfooler_tweets.csv')
print(df.shape)
df.drop_duplicates(subset=['original_text'],inplace=True, ignore_index=True)
df=df[0:int(0.7*len(df))]
df['original_text']=cleanText(df['original_text'])
df['perturbed_text']=cleanText(df['perturbed_text'])
df['original_text']= df['original_text'].apply(lambda x: x.encode('utf-8').decode('ascii', errors='ignore').strip())
df['perturbed_text']= df['perturbed_text'].apply(lambda x: x.encode('utf-8').decode('ascii', errors='ignore').strip())
print(df.shape)
df.to_csv('cleaned_textfooler_tweets.csv')
# Out:
# (75494, 9)
# (15556, 9)

# %%
textgan = TrtansformerGAN(
    dataframe = df, 
    bert_tokenizer = bert_tokenizer, 
    bert_classifier = bert_for_seq_classification, 
    gpt_tokenizer = gpt2_tokenizer, 
    gpt_generator = gpt2_model, 
    num_labels = num_labels)

# %%
OpenAIGPT2_generator, BERT_discriminator, d_loss_list, g_loss_list, generated_review_list, real_review_list = textgan.train()
# Out:
# Epoch 1/2000
# ----------
# /home/gridsan/SW26425/.conda/envs/textgan/lib/python3.6/site-packages/ipykernel_launcher.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/gridsan/SW26425/.conda/envs/textgan/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Discriminator Loss: tensor(0.8252, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.3477, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 2/2000
# ----------
# Discriminator Loss: tensor(0.8236, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.2776, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 3/2000
# ----------
# Discriminator Loss: tensor(0.7836, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.2600, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 4/2000
# ----------
# Discriminator Loss: tensor(0.7433, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.0778, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 5/2000
# ----------
# Discriminator Loss: tensor(0.6600, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(0.9402, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 6/2000
# ----------
# Discriminator Loss: tensor(0.5660, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(0.7384, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 7/2000
# ----------
# Discriminator Loss: tensor(0.5148, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(0.6309, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 8/2000
# ----------
# Discriminator Loss: tensor(0.4997, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(0.7907, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 9/2000
# ----------
# Discriminator Loss: tensor(0.5185, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(0.9831, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 10/2000
# ----------
# Discriminator Loss: tensor(0.3711, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.2431, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 11/2000
# ----------
# Discriminator Loss: tensor(0.4416, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.2857, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 12/2000
# ----------
# Discriminator Loss: tensor(0.4551, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.2264, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 13/2000
# ----------
# Discriminator Loss: tensor(0.3644, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.1900, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 14/2000
# ----------
# Discriminator Loss: tensor(0.4220, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.1891, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 15/2000
# ----------
# Discriminator Loss: tensor(0.2211, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.6269, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 16/2000
# ----------
# Discriminator Loss: tensor(0.2314, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.6968, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 17/2000
# ----------
# Discriminator Loss: tensor(0.2485, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.8855, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 18/2000
# ----------
# Discriminator Loss: tensor(0.1952, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.9181, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 19/2000
# ----------
# Discriminator Loss: tensor(0.2170, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.4861, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 20/2000
# ----------
# Discriminator Loss: tensor(0.4092, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.7577, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 21/2000
# ----------
# Discriminator Loss: tensor(0.0820, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.4305, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 22/2000
# ----------
# Discriminator Loss: tensor(0.1202, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.5722, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 23/2000
# ----------
# Discriminator Loss: tensor(0.2090, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.5730, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 24/2000
# ----------
# Discriminator Loss: tensor(0.0760, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.7642, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 25/2000
# ----------
# Discriminator Loss: tensor(0.2489, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9388, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 26/2000
# ----------
# Discriminator Loss: tensor(0.4074, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.7345, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 27/2000
# ----------
# Discriminator Loss: tensor(0.0469, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4419, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 28/2000
# ----------
# Discriminator Loss: tensor(0.1155, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6065, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 29/2000
# ----------
# Discriminator Loss: tensor(0.4093, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6914, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 30/2000
# ----------
# Discriminator Loss: tensor(0.3459, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6343, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 31/2000
# ----------
# Discriminator Loss: tensor(0.1798, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7503, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 32/2000
# ----------
# Discriminator Loss: tensor(0.1456, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9677, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 33/2000
# ----------
# Discriminator Loss: tensor(0.0483, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.5947, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 34/2000
# ----------
# Discriminator Loss: tensor(0.2754, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4834, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 35/2000
# ----------
# Discriminator Loss: tensor(0.3106, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6459, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 36/2000
# ----------
# Discriminator Loss: tensor(0.1343, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2771, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 37/2000
# ----------
# Discriminator Loss: tensor(0.0447, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9127, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 38/2000
# ----------
# Discriminator Loss: tensor(0.0774, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.0398, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 39/2000
# ----------
# Discriminator Loss: tensor(0.2242, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2164, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 40/2000
# ----------
# Discriminator Loss: tensor(0.2349, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9352, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 41/2000
# ----------
# Discriminator Loss: tensor(0.0998, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1456, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 42/2000
# ----------
# Discriminator Loss: tensor(0.1694, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3890, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 43/2000
# ----------
# Discriminator Loss: tensor(0.0767, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4466, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 44/2000
# ----------
# Discriminator Loss: tensor(0.1887, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5041, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 45/2000
# ----------
# Discriminator Loss: tensor(0.0845, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2239, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 46/2000
# ----------
# Discriminator Loss: tensor(0.0163, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2504, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 47/2000
# ----------
# Discriminator Loss: tensor(0.2173, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8044, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 48/2000
# ----------
# Discriminator Loss: tensor(0.2687, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.8842, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 49/2000
# ----------
# Discriminator Loss: tensor(0.7513, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.2769, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 50/2000
# ----------
# Discriminator Loss: tensor(0.1744, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6225, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 51/2000
# ----------
# Discriminator Loss: tensor(0.4728, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2716, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 52/2000
# ----------
# Discriminator Loss: tensor(0.2746, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9864, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 53/2000
# ----------
# Discriminator Loss: tensor(0.1516, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2339, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 54/2000
# ----------
# Discriminator Loss: tensor(0.2050, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7232, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 55/2000
# ----------
# Discriminator Loss: tensor(0.0799, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7513, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 56/2000
# ----------
# Discriminator Loss: tensor(0.1396, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7831, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 57/2000
# ----------
# Discriminator Loss: tensor(0.2287, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.7770, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 58/2000
# ----------
# Discriminator Loss: tensor(0.2012, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6433, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 59/2000
# ----------
# Discriminator Loss: tensor(0.3606, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.0432, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 60/2000
# ----------
# Discriminator Loss: tensor(0.4642, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4060, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 61/2000
# ----------
# Discriminator Loss: tensor(0.1822, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6158, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 62/2000
# ----------
# Discriminator Loss: tensor(0.0263, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3629, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 63/2000
# ----------
# Discriminator Loss: tensor(0.0246, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4525, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 64/2000
# ----------
# Discriminator Loss: tensor(0.2499, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4197, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 65/2000
# ----------
# Discriminator Loss: tensor(0.0269, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9093, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 66/2000
# ----------
# Discriminator Loss: tensor(0.2169, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3320, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 67/2000
# ----------
# Discriminator Loss: tensor(0.1459, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4814, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 68/2000
# ----------
# Discriminator Loss: tensor(0.3194, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4872, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 69/2000
# ----------
# Discriminator Loss: tensor(0.2946, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7928, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 70/2000
# ----------
# Discriminator Loss: tensor(0.2697, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.5524, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 71/2000
# ----------
# Discriminator Loss: tensor(0.5833, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9559, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 72/2000
# ----------
# Discriminator Loss: tensor(0.5687, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9670, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 73/2000
# ----------
# Discriminator Loss: tensor(0.3717, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6762, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 74/2000
# ----------
# Discriminator Loss: tensor(1.0634, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7794, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 75/2000
# ----------
# Discriminator Loss: tensor(0.2138, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7870, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 76/2000
# ----------
# Discriminator Loss: tensor(0.1334, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8167, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 77/2000
# ----------
# Discriminator Loss: tensor(0.2013, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.5804, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 78/2000
# ----------
# Discriminator Loss: tensor(0.2611, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.0563, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 79/2000
# ----------
# Discriminator Loss: tensor(0.2955, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9602, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 80/2000
# ----------
# Discriminator Loss: tensor(0.6835, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6242, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 81/2000
# ----------
# Discriminator Loss: tensor(0.3805, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2753, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 82/2000
# ----------
# Discriminator Loss: tensor(0.2850, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.5664, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 83/2000
# ----------
# Discriminator Loss: tensor(0.1890, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.0913, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 84/2000
# ----------
# Discriminator Loss: tensor(0.2160, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.9687, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 85/2000
# ----------
# Discriminator Loss: tensor(0.3565, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(1.9534, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 86/2000
# ----------
# Discriminator Loss: tensor(0.1982, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.3628, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 87/2000
# ----------
# Discriminator Loss: tensor(0.1019, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.7197, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 88/2000
# ----------
# Discriminator Loss: tensor(0.1289, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.8760, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 89/2000
# ----------
# Discriminator Loss: tensor(0.1280, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.7753, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 90/2000
# ----------
# Discriminator Loss: tensor(0.1141, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.9865, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 91/2000
# ----------
# Discriminator Loss: tensor(0.0368, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4973, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 92/2000
# ----------
# Discriminator Loss: tensor(0.1883, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.5682, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 93/2000
# ----------
# Discriminator Loss: tensor(0.0659, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.3139, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 94/2000
# ----------
# Discriminator Loss: tensor(0.6236, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(2.8786, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 95/2000
# ----------
# Discriminator Loss: tensor(0.1364, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7749, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 96/2000
# ----------
# Discriminator Loss: tensor(0.1678, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7848, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 97/2000
# ----------
# Discriminator Loss: tensor(0.1707, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8713, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 98/2000
# ----------
# Discriminator Loss: tensor(0.0816, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2119, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 99/2000
# ----------
# Discriminator Loss: tensor(0.3001, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4259, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 100/2000
# ----------
# Discriminator Loss: tensor(0.1881, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8321, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 101/2000
# ----------
# Discriminator Loss: tensor(0.1443, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7389, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 102/2000
# ----------
# Discriminator Loss: tensor(0.2605, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.0613, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 103/2000
# ----------
# Discriminator Loss: tensor(0.0811, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.5917, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 104/2000
# ----------
# Discriminator Loss: tensor(0.1759, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8679, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 105/2000
# ----------
# Discriminator Loss: tensor(0.0567, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1008, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 106/2000
# ----------
# Discriminator Loss: tensor(0.2785, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6794, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 107/2000
# ----------
# Discriminator Loss: tensor(0.0378, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.3937, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 108/2000
# ----------
# Discriminator Loss: tensor(0.1103, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4103, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 109/2000
# ----------
# Discriminator Loss: tensor(0.2684, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.0527, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 110/2000
# ----------
# Discriminator Loss: tensor(0.4090, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6539, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 111/2000
# ----------
# Discriminator Loss: tensor(0.2762, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9759, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 112/2000
# ----------
# Discriminator Loss: tensor(0.2983, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2832, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 113/2000
# ----------
# Discriminator Loss: tensor(0.0965, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0506, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 114/2000
# ----------
# Discriminator Loss: tensor(0.0146, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3023, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 115/2000
# ----------
# Discriminator Loss: tensor(0.0166, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3009, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 116/2000
# ----------
# Discriminator Loss: tensor(0.0652, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1832, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 117/2000
# ----------
# Discriminator Loss: tensor(0.2962, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3370, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 118/2000
# ----------
# Discriminator Loss: tensor(0.1442, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2257, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 119/2000
# ----------
# Discriminator Loss: tensor(0.2103, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2482, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 120/2000
# ----------
# Discriminator Loss: tensor(0.0167, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8040, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 121/2000
# ----------
# Discriminator Loss: tensor(0.0241, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6360, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 122/2000
# ----------
# Discriminator Loss: tensor(0.2353, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1763, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 123/2000
# ----------
# Discriminator Loss: tensor(0.3116, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7006, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 124/2000
# ----------
# Discriminator Loss: tensor(0.1032, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9931, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 125/2000
# ----------
# Discriminator Loss: tensor(0.0237, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3681, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 126/2000
# ----------
# Discriminator Loss: tensor(0.0214, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5010, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 127/2000
# ----------
# Discriminator Loss: tensor(0.0283, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3712, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 128/2000
# ----------
# Discriminator Loss: tensor(0.2691, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9654, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 129/2000
# ----------
# Discriminator Loss: tensor(0.1821, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7915, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 130/2000
# ----------
# Discriminator Loss: tensor(0.1017, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.0326, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 131/2000
# ----------
# Discriminator Loss: tensor(0.1556, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.5030, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 132/2000
# ----------
# Discriminator Loss: tensor(0.1443, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2766, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 133/2000
# ----------
# Discriminator Loss: tensor(0.3113, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.9579, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 134/2000
# ----------
# Discriminator Loss: tensor(0.0242, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9408, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 135/2000
# ----------
# Discriminator Loss: tensor(0.0585, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3984, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 136/2000
# ----------
# Discriminator Loss: tensor(0.1143, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7635, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 137/2000
# ----------
# Discriminator Loss: tensor(0.2455, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6518, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 138/2000
# ----------
# Discriminator Loss: tensor(0.1423, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4382, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 139/2000
# ----------
# Discriminator Loss: tensor(0.0987, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2372, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 140/2000
# ----------
# Discriminator Loss: tensor(0.0829, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6149, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 141/2000
# ----------
# Discriminator Loss: tensor(0.0781, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4238, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 142/2000
# ----------
# Discriminator Loss: tensor(0.1391, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0759, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 143/2000
# ----------
# Discriminator Loss: tensor(0.3548, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1458, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 144/2000
# ----------
# Discriminator Loss: tensor(0.4105, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.0369, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 145/2000
# ----------
# Discriminator Loss: tensor(0.1692, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8537, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 146/2000
# ----------
# Discriminator Loss: tensor(0.1682, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2414, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 147/2000
# ----------
# Discriminator Loss: tensor(0.1609, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6513, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 148/2000
# ----------
# Discriminator Loss: tensor(0.0849, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0887, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 149/2000
# ----------
# Discriminator Loss: tensor(0.2954, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2864, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 150/2000
# ----------
# Discriminator Loss: tensor(0.0254, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6406, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 151/2000
# ----------
# Discriminator Loss: tensor(0.0260, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9065, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 152/2000
# ----------
# Discriminator Loss: tensor(0.0690, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1809, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 153/2000
# ----------
# Discriminator Loss: tensor(0.1783, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2811, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 154/2000
# ----------
# Discriminator Loss: tensor(0.1022, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1251, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 155/2000
# ----------
# Discriminator Loss: tensor(0.1365, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3786, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 156/2000
# ----------
# Discriminator Loss: tensor(0.0347, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9576, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 157/2000
# ----------
# Discriminator Loss: tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0224, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 158/2000
# ----------
# Discriminator Loss: tensor(0.0226, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9486, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 159/2000
# ----------
# Discriminator Loss: tensor(0.0474, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0790, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 160/2000
# ----------
# Discriminator Loss: tensor(0.0197, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2004, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 161/2000
# ----------
# Discriminator Loss: tensor(0.1715, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8936, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 162/2000
# ----------
# Discriminator Loss: tensor(0.1370, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2428, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 163/2000
# ----------
# Discriminator Loss: tensor(0.2083, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7332, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 164/2000
# ----------
# Discriminator Loss: tensor(0.2217, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1614, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 165/2000
# ----------
# Discriminator Loss: tensor(0.0277, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2936, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 166/2000
# ----------
# Discriminator Loss: tensor(0.0173, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8130, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 167/2000
# ----------
# Discriminator Loss: tensor(0.1413, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2943, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 168/2000
# ----------
# Discriminator Loss: tensor(0.2293, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3488, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 169/2000
# ----------
# Discriminator Loss: tensor(0.1555, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.2272, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 170/2000
# ----------
# Discriminator Loss: tensor(0.0792, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5399, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 171/2000
# ----------
# Discriminator Loss: tensor(0.0487, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7276, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 172/2000
# ----------
# Discriminator Loss: tensor(0.1062, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9351, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 173/2000
# ----------
# Discriminator Loss: tensor(0.0421, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9037, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 174/2000
# ----------
# Discriminator Loss: tensor(0.1785, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9774, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 175/2000
# ----------
# Discriminator Loss: tensor(0.0898, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9649, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 176/2000
# ----------
# Discriminator Loss: tensor(0.0898, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8781, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 177/2000
# ----------
# Discriminator Loss: tensor(0.2245, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3031, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 178/2000
# ----------
# Discriminator Loss: tensor(0.0367, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3082, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 179/2000
# ----------
# Discriminator Loss: tensor(0.1964, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6645, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 180/2000
# ----------
# Discriminator Loss: tensor(0.2304, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.0619, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 181/2000
# ----------
# Discriminator Loss: tensor(0.2003, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.2614, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 182/2000
# ----------
# Discriminator Loss: tensor(0.1117, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.7203, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 183/2000
# ----------
# Discriminator Loss: tensor(0.0550, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.0785, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 184/2000
# ----------
# Discriminator Loss: tensor(0.0376, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4749, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 185/2000
# ----------
# Discriminator Loss: tensor(0.1836, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.0557, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 186/2000
# ----------
# Discriminator Loss: tensor(0.0306, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5597, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 187/2000
# ----------
# Discriminator Loss: tensor(0.0296, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9553, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 188/2000
# ----------
# Discriminator Loss: tensor(0.0166, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8091, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 189/2000
# ----------
# Discriminator Loss: tensor(0.0718, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6943, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 190/2000
# ----------
# Discriminator Loss: tensor(0.2596, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4601, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 191/2000
# ----------
# Discriminator Loss: tensor(0.0735, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0784, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 192/2000
# ----------
# Discriminator Loss: tensor(0.0336, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8332, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 193/2000
# ----------
# Discriminator Loss: tensor(0.0108, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1912, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 194/2000
# ----------
# Discriminator Loss: tensor(0.2366, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9214, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 195/2000
# ----------
# Discriminator Loss: tensor(0.0160, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1948, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 196/2000
# ----------
# Discriminator Loss: tensor(0.0129, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3526, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 197/2000
# ----------
# Discriminator Loss: tensor(0.0130, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4340, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 198/2000
# ----------
# Discriminator Loss: tensor(0.0506, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2903, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 199/2000
# ----------
# Discriminator Loss: tensor(0.0368, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3657, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 200/2000
# ----------
# Discriminator Loss: tensor(0.0118, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.6256, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 201/2000
# ----------
# Discriminator Loss: tensor(0.0280, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3611, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 202/2000
# ----------
# Discriminator Loss: tensor(0.0101, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.7402, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 203/2000
# ----------
# Discriminator Loss: tensor(0.0116, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5754, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 204/2000
# ----------
# Discriminator Loss: tensor(0.1559, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4352, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 205/2000
# ----------
# Discriminator Loss: tensor(0.0231, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.9329, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 206/2000
# ----------
# Discriminator Loss: tensor(0.3034, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4618, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 207/2000
# ----------
# Discriminator Loss: tensor(0.3279, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3925, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 208/2000
# ----------
# Discriminator Loss: tensor(0.3499, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3104, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 209/2000
# ----------
# Discriminator Loss: tensor(0.0662, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.7915, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 210/2000
# ----------
# Discriminator Loss: tensor(0.0643, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4894, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 211/2000
# ----------
# Discriminator Loss: tensor(0.0436, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3695, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 212/2000
# ----------
# Discriminator Loss: tensor(0.1944, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.3507, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 213/2000
# ----------
# Discriminator Loss: tensor(0.0119, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.6352, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 214/2000
# ----------
# Discriminator Loss: tensor(0.0082, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5738, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 215/2000
# ----------
# Discriminator Loss: tensor(0.0578, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9181, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 216/2000
# ----------
# Discriminator Loss: tensor(0.0843, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2195, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 217/2000
# ----------
# Discriminator Loss: tensor(0.1536, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5955, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 218/2000
# ----------
# Discriminator Loss: tensor(0.1062, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0114, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 219/2000
# ----------
# Discriminator Loss: tensor(0.0219, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5771, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 220/2000
# ----------
# Discriminator Loss: tensor(0.0618, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1669, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 221/2000
# ----------
# Discriminator Loss: tensor(0.1066, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5864, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 222/2000
# ----------
# Discriminator Loss: tensor(0.0601, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0927, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 223/2000
# ----------
# Discriminator Loss: tensor(0.0493, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0965, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 224/2000
# ----------
# Discriminator Loss: tensor(0.0612, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2702, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 225/2000
# ----------
# Discriminator Loss: tensor(0.0172, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.6319, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 226/2000
# ----------
# Discriminator Loss: tensor(0.0585, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4454, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 227/2000
# ----------
# Discriminator Loss: tensor(0.0118, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.6736, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 228/2000
# ----------
# Discriminator Loss: tensor(0.1155, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2789, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 229/2000
# ----------
# Discriminator Loss: tensor(0.0645, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.7549, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 230/2000
# ----------
# Discriminator Loss: tensor(0.2010, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2009, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 231/2000
# ----------
# Discriminator Loss: tensor(0.0892, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.8224, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 232/2000
# ----------
# Discriminator Loss: tensor(0.2753, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.7573, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 233/2000
# ----------
# Discriminator Loss: tensor(0.0735, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2568, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 234/2000
# ----------
# Discriminator Loss: tensor(0.0303, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5682, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 235/2000
# ----------
# Discriminator Loss: tensor(0.0907, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7275, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 236/2000
# ----------
# Discriminator Loss: tensor(0.0682, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4190, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 237/2000
# ----------
# Discriminator Loss: tensor(0.0105, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4926, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 238/2000
# ----------
# Discriminator Loss: tensor(0.0139, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5759, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 239/2000
# ----------
# Discriminator Loss: tensor(0.1504, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3289, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 240/2000
# ----------
# Discriminator Loss: tensor(0.0637, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7654, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 241/2000
# ----------
# Discriminator Loss: tensor(0.1404, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.6269, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 242/2000
# ----------
# Discriminator Loss: tensor(0.0258, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.1725, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 243/2000
# ----------
# Discriminator Loss: tensor(0.0640, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.4813, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 244/2000
# ----------
# Discriminator Loss: tensor(0.0570, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.1980, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 245/2000
# ----------
# Discriminator Loss: tensor(0.2423, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4805, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 246/2000
# ----------
# Discriminator Loss: tensor(0.0236, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2342, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 247/2000
# ----------
# Discriminator Loss: tensor(0.0793, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1953, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 248/2000
# ----------
# Discriminator Loss: tensor(0.3344, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7720, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 249/2000
# ----------
# Discriminator Loss: tensor(0.0908, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.9545, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 250/2000
# ----------
# Discriminator Loss: tensor(0.0331, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2070, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 251/2000
# ----------
# Discriminator Loss: tensor(0.1240, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0718, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 252/2000
# ----------
# Discriminator Loss: tensor(0.1002, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1497, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 253/2000
# ----------
# Discriminator Loss: tensor(0.2684, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.3825, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 254/2000
# ----------
# Discriminator Loss: tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.6396, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 255/2000
# ----------
# Discriminator Loss: tensor(0.0096, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2828, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 256/2000
# ----------
# Discriminator Loss: tensor(0.0279, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.5020, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 257/2000
# ----------
# Discriminator Loss: tensor(0.3018, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4901, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 258/2000
# ----------
# Discriminator Loss: tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8907, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 259/2000
# ----------
# Discriminator Loss: tensor(0.1128, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.5595, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 260/2000
# ----------
# Discriminator Loss: tensor(0.0622, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(3.8867, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 261/2000
# ----------
# Discriminator Loss: tensor(0.0765, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.6423, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 262/2000
# ----------
# Discriminator Loss: tensor(0.0143, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.8944, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 263/2000
# ----------
# Discriminator Loss: tensor(0.0689, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.4761, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 264/2000
# ----------
# Discriminator Loss: tensor(0.0092, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.2272, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 265/2000
# ----------
# Discriminator Loss: tensor(0.0714, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.4350, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 266/2000
# ----------
# Discriminator Loss: tensor(0.0625, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.1450, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 267/2000
# ----------
# Discriminator Loss: tensor(0.0289, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(4.7254, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 268/2000
# ----------
# Discriminator Loss: tensor(0.1122, device='cuda:0', grad_fn=<MeanBackward0>)
# Generator Loss: tensor(5.0726, device='cuda:0', grad_fn=<MeanBackward0>)
#
# Epoch 269/2000
# ----------
# Discriminator Loss: tensor(0.0885, device='cuda:0', grad_fn=<MeanBackward0>)
# ...
# Epoch 1410/2000
# ----------
# Epoch 1411/2000
# ----------
# Epoch 1412/2000
# ----------
# Epoch 1413/2000
# ----------
# Epoch 1414/2000
# ----------
# Epoch 1415/2000
# ----------
# Epoch 1416/2000
# ----------
# Epoch 1417/2000
# ----------
# Epoch 1418/2000
# ----------
# Epoch 1419/2000
# ----------
# Epoch 1420/2000
# ----------
# Epoch 1421/2000
# ----------
# Epoch 1422/2000
# ----------
# Epoch 1423/2000
# ----------
# Epoch 1424/2000
# ----------
# Epoch 1425/2000
# ----------
# Epoch 1426/2000
# ----------
# Epoch 1427/2000
# ----------
# Epoch 1428/2000
# ----------
# Epoch 1429/2000
# ----------
# Epoch 1430/2000
# ----------
# Epoch 1431/2000
# ----------
# Epoch 1432/2000
# ----------
# Epoch 1433/2000
# ----------
# Epoch 1434/2000
# ----------
# Epoch 1435/2000
# ----------
# Epoch 1436/2000
# ----------
# Epoch 1437/2000
# ----------
# Epoch 1438/2000
# ----------
# Epoch 1439/2000
# ----------
# Epoch 1440/2000
# ----------
# Epoch 1441/2000
# ----------
# Epoch 1442/2000
# ----------
# Epoch 1443/2000
# ----------
# Epoch 1444/2000
# ----------
# Epoch 1445/2000
# ----------
# Epoch 1446/2000
# ----------
# Epoch 1447/2000
# ----------
# Epoch 1448/2000
# ----------
# Epoch 1449/2000
# ----------
# Epoch 1450/2000
# ----------
# Epoch 1451/2000
# ----------
# Epoch 1452/2000
# ----------
# Epoch 1453/2000
# ----------
# Epoch 1454/2000
# ----------
# Epoch 1455/2000
# ----------
# Epoch 1456/2000
# ----------
# Epoch 1457/2000
# ----------
# Epoch 1458/2000
# ----------
# Epoch 1459/2000
# ----------
# Epoch 1460/2000
# ----------
# Epoch 1461/2000
# ----------
# Epoch 1462/2000
# ----------
# Epoch 1463/2000
# ----------
# Epoch 1464/2000
# ----------
# Epoch 1465/2000
# ----------
# Epoch 1466/2000
# ----------
# Epoch 1467/2000
# ----------
# Epoch 1468/2000
# ----------
# Epoch 1469/2000
# ----------
# Epoch 1470/2000
# ----------
# Epoch 1471/2000
# ----------
# Epoch 1472/2000
# ----------
# Epoch 1473/2000
# ----------
# Epoch 1474/2000
# ----------
# Epoch 1475/2000
# ----------
# Epoch 1476/2000
# ----------
# Epoch 1477/2000
# ----------
# Epoch 1478/2000
# ----------
# Epoch 1479/2000
# ----------
# Epoch 1480/2000
# ----------
# Epoch 1481/2000
# ----------
# Epoch 1482/2000
# ----------
# Epoch 1483/2000
# ----------
# Epoch 1484/2000
# ----------
# Epoch 1485/2000
# ----------
# Epoch 1486/2000
# ----------
# Epoch 1487/2000
# ----------
# Epoch 1488/2000
# ----------
# Epoch 1489/2000
# ----------
# Epoch 1490/2000
# ----------
# Epoch 1491/2000
# ----------
# Epoch 1492/2000
# ----------
# Epoch 1493/2000
# ----------
# Epoch 1494/2000
# ----------
# Epoch 1495/2000
# ----------
# Epoch 1496/2000
# ----------
# Epoch 1497/2000
# ----------
# Epoch 1498/2000
# ----------
# Epoch 1499/2000
# ----------
# Epoch 1500/2000
# ----------
# Epoch 1501/2000
# ----------
# Epoch 1502/2000
# ----------
# Epoch 1503/2000
# ----------
# Epoch 1504/2000
# ----------
# Epoch 1505/2000
# ----------
# Epoch 1506/2000
# ----------
# Epoch 1507/2000
# ----------
# Epoch 1508/2000
# ----------
# Epoch 1509/2000
# ----------
# Epoch 1510/2000
# ----------
# Epoch 1511/2000
# ----------
# Epoch 1512/2000
# ----------
# Epoch 1513/2000
# ----------
# Epoch 1514/2000
# ----------
# Epoch 1515/2000
# ----------
# Epoch 1516/2000
# ----------
# Epoch 1517/2000
# ----------
# Epoch 1518/2000
# ----------
# Epoch 1519/2000
# ----------
# Epoch 1520/2000
# ----------
# Epoch 1521/2000
# ----------
# Epoch 1522/2000
# ----------
# Epoch 1523/2000
# ----------
# Epoch 1524/2000
# ----------
# Epoch 1525/2000
# ----------
# Epoch 1526/2000
# ----------
# Epoch 1527/2000
# ----------
# Epoch 1528/2000
# ----------
# Epoch 1529/2000
# ----------
# Epoch 1530/2000
# ----------
# Epoch 1531/2000
# ----------
# Epoch 1532/2000
# ----------
# Epoch 1533/2000
# ----------
# Epoch 1534/2000
# ----------
# Epoch 1535/2000
# ----------
# Epoch 1536/2000
# ----------
# Epoch 1537/2000
# ----------
# Epoch 1538/2000
# ----------
# Epoch 1539/2000
# ----------
# Epoch 1540/2000
# ----------
# Epoch 1541/2000
# ----------
# Epoch 1542/2000
# ----------
# Epoch 1543/2000
# ----------
# Epoch 1544/2000
# ----------
# Epoch 1545/2000
# ----------
# Epoch 1546/2000
# ----------
# Epoch 1547/2000
# ----------
# Epoch 1548/2000
# ----------
# Epoch 1549/2000
# ----------
# Epoch 1550/2000
# ----------
# Epoch 1551/2000
# ----------
# Epoch 1552/2000
# ----------
# Epoch 1553/2000
# ----------
# Epoch 1554/2000
# ----------
# Epoch 1555/2000
# ----------
# Epoch 1556/2000
# ----------
# Epoch 1557/2000
# ----------
# Epoch 1558/2000
# ----------
# Epoch 1559/2000
# ----------
# Epoch 1560/2000
# ----------
# Epoch 1561/2000
# ----------
# Epoch 1562/2000
# ----------
# Epoch 1563/2000
# ----------
# Epoch 1564/2000
# ----------
# Epoch 1565/2000
# ----------
# Epoch 1566/2000
# ----------
# Epoch 1567/2000
# ----------
# Epoch 1568/2000
# ----------
# Epoch 1569/2000
# ----------
# Epoch 1570/2000
# ----------
# Epoch 1571/2000
# ----------
# Epoch 1572/2000
# ----------
# Epoch 1573/2000
# ----------
# Epoch 1574/2000
# ----------
# Epoch 1575/2000
# ----------
# Epoch 1576/2000
# ----------
# Epoch 1577/2000
# ----------
# Epoch 1578/2000
# ----------
# Epoch 1579/2000
# ----------
# Epoch 1580/2000
# ----------
# Epoch 1581/2000
# ----------
# Epoch 1582/2000
# ----------
# Epoch 1583/2000
# ----------
# Epoch 1584/2000
# ----------
# Epoch 1585/2000
# ----------
# Epoch 1586/2000
# ----------
# Epoch 1587/2000
# ----------
# Epoch 1588/2000
# ----------
# Epoch 1589/2000
# ----------
# Epoch 1590/2000
# ----------
# Epoch 1591/2000
# ----------
# Epoch 1592/2000
# ----------
# Epoch 1593/2000
# ----------
# Epoch 1594/2000
# ----------
# Epoch 1595/2000
# ----------
# Epoch 1596/2000
# ----------
# Epoch 1597/2000
# ----------
# Epoch 1598/2000
# ----------
# Epoch 1599/2000
# ----------
# Epoch 1600/2000
# ----------
# Epoch 1601/2000
# ----------
# Epoch 1602/2000
# ----------
# Epoch 1603/2000
# ----------
# Epoch 1604/2000
# ----------
# Epoch 1605/2000
# ----------
# Epoch 1606/2000
# ----------
# Epoch 1607/2000
# ----------
# Epoch 1608/2000
# ----------
# Epoch 1609/2000
# ----------
# Epoch 1610/2000
# ----------
# Epoch 1611/2000
# ----------
# Epoch 1612/2000
# ----------
# Epoch 1613/2000
# ----------
# Epoch 1614/2000
# ----------
# Epoch 1615/2000
# ----------
# Epoch 1616/2000
# ----------
# Epoch 1617/2000
# ----------
# Epoch 1618/2000
# ----------
# Epoch 1619/2000
# ----------
# Epoch 1620/2000
# ----------
# Epoch 1621/2000
# ----------
# Epoch 1622/2000
# ----------
# Epoch 1623/2000
# ----------
# Epoch 1624/2000
# ----------
# Epoch 1625/2000
# ----------
# Epoch 1626/2000
# ----------
# Epoch 1627/2000
# ----------
# Epoch 1628/2000
# ----------
# Epoch 1629/2000
# ----------
# Epoch 1630/2000
# ----------
# Epoch 1631/2000
# ----------
# Epoch 1632/2000
# ----------
# Epoch 1633/2000
# ----------
# Epoch 1634/2000
# ----------
# Epoch 1635/2000
# ----------
# Epoch 1636/2000
# ----------
# Epoch 1637/2000
# ----------
# Epoch 1638/2000
# ----------
# Epoch 1639/2000
# ----------
# Epoch 1640/2000
# ----------
# Epoch 1641/2000
# ----------
# Epoch 1642/2000
# ----------
# Epoch 1643/2000
# ----------
# Epoch 1644/2000
# ----------
# Epoch 1645/2000
# ----------
# Epoch 1646/2000
# ----------
# Epoch 1647/2000
# ----------
# Epoch 1648/2000
# ----------
# Epoch 1649/2000
# ----------
# Epoch 1650/2000
# ----------
# Epoch 1651/2000
# ----------
# Epoch 1652/2000
# ----------
# Epoch 1653/2000
# ----------
# Epoch 1654/2000
# ----------
# Epoch 1655/2000
# ----------
# Epoch 1656/2000
# ----------
# Epoch 1657/2000
# ----------
# Epoch 1658/2000
# ----------
# Epoch 1659/2000
# ----------
# Epoch 1660/2000
# ----------
# Epoch 1661/2000
# ----------
# Epoch 1662/2000
# ----------
# Epoch 1663/2000
# ----------
# Epoch 1664/2000
# ----------
# Epoch 1665/2000
# ----------
# Epoch 1666/2000
# ----------
# Epoch 1667/2000
# ----------
# Epoch 1668/2000
# ----------
# Epoch 1669/2000
# ----------
# Epoch 1670/2000
# ----------
# Epoch 1671/2000
# ----------
# Epoch 1672/2000
# ----------
# Epoch 1673/2000
# ----------
# Epoch 1674/2000
# ----------
# Epoch 1675/2000
# ----------
# Epoch 1676/2000
# ----------
# Epoch 1677/2000
# ----------
# Epoch 1678/2000
# ----------
# Epoch 1679/2000
# ----------
# Epoch 1680/2000
# ----------
# Epoch 1681/2000
# ----------
# Epoch 1682/2000
# ----------
# Epoch 1683/2000
# ----------
# Epoch 1684/2000
# ----------
# Epoch 1685/2000
# ----------
# Epoch 1686/2000
# ----------
# Epoch 1687/2000
# ----------
# Epoch 1688/2000
# ----------
# Epoch 1689/2000
# ----------
# Epoch 1690/2000
# ----------
# Epoch 1691/2000
# ----------
# Epoch 1692/2000
# ----------
# Epoch 1693/2000
# ----------
# Epoch 1694/2000
# ----------
# Epoch 1695/2000
# ----------
# Epoch 1696/2000
# ----------
# Epoch 1697/2000
# ----------
# Epoch 1698/2000
# ----------
# Epoch 1699/2000
# ----------
# Epoch 1700/2000
# ----------
# Epoch 1701/2000
# ----------
# Epoch 1702/2000
# ----------
# Epoch 1703/2000
# ----------
# Epoch 1704/2000
# ----------
# Epoch 1705/2000
# ----------
# Epoch 1706/2000
# ----------
# Epoch 1707/2000
# ----------
# Epoch 1708/2000
# ----------
# Epoch 1709/2000
# ----------
# Epoch 1710/2000
# ----------
# Epoch 1711/2000
# ----------
# Epoch 1712/2000
# ----------
# Epoch 1713/2000
# ----------
# Epoch 1714/2000
# ----------
# Epoch 1715/2000
# ----------
# Epoch 1716/2000
# ----------
# Epoch 1717/2000
# ----------
# Epoch 1718/2000
# ----------
# Epoch 1719/2000
# ----------
# Epoch 1720/2000
# ----------
# Epoch 1721/2000
# ----------
# Epoch 1722/2000
# ----------
# Epoch 1723/2000
# ----------
# Epoch 1724/2000
# ----------
# Epoch 1725/2000
# ----------
# Epoch 1726/2000
# ----------
# Epoch 1727/2000
# ----------
# Epoch 1728/2000
# ----------
# Epoch 1729/2000
# ----------
# Epoch 1730/2000
# ----------
# Epoch 1731/2000
# ----------
# Epoch 1732/2000
# ----------
# Epoch 1733/2000
# ----------
# Epoch 1734/2000
# ----------
# Epoch 1735/2000
# ----------
# Epoch 1736/2000
# ----------
# Epoch 1737/2000
# ----------
# Epoch 1738/2000
# ----------
# Epoch 1739/2000
# ----------
# Epoch 1740/2000
# ----------
# Epoch 1741/2000
# ----------
# Epoch 1742/2000
# ----------
# Epoch 1743/2000
# ----------
# Epoch 1744/2000
# ----------
# Epoch 1745/2000
# ----------
# Epoch 1746/2000
# ----------
# Epoch 1747/2000
# ----------
# Epoch 1748/2000
# ----------
# Epoch 1749/2000
# ----------
# Epoch 1750/2000
# ----------
# Epoch 1751/2000
# ----------
# Epoch 1752/2000
# ----------
# Epoch 1753/2000
# ----------
# Epoch 1754/2000
# ----------
# Epoch 1755/2000
# ----------
# Epoch 1756/2000
# ----------
# Epoch 1757/2000
# ----------
# Epoch 1758/2000
# ----------
# Epoch 1759/2000
# ----------
# Epoch 1760/2000
# ----------
# Epoch 1761/2000
# ----------
# Epoch 1762/2000
# ----------
# Epoch 1763/2000
# ----------
# Epoch 1764/2000
# ----------
# Epoch 1765/2000
# ----------
# Epoch 1766/2000
# ----------
# Epoch 1767/2000
# ----------
# Epoch 1768/2000
# ----------
# Epoch 1769/2000
# ----------
# Epoch 1770/2000
# ----------
# Epoch 1771/2000
# ----------
# Epoch 1772/2000
# ----------
# Epoch 1773/2000
# ----------
# Epoch 1774/2000
# ----------
# Epoch 1775/2000
# ----------
# Epoch 1776/2000
# ----------
# Epoch 1777/2000
# ----------
# Epoch 1778/2000
# ----------
# Epoch 1779/2000
# ----------
# Epoch 1780/2000
# ----------
# Epoch 1781/2000
# ----------
# Epoch 1782/2000
# ----------
# Epoch 1783/2000
# ----------
# Epoch 1784/2000
# ----------
# Epoch 1785/2000
# ----------
# Epoch 1786/2000
# ----------
# Epoch 1787/2000
# ----------
# Epoch 1788/2000
# ----------
# Epoch 1789/2000
# ----------
# Epoch 1790/2000
# ----------
# Epoch 1791/2000
# ----------
# Epoch 1792/2000
# ----------
# Epoch 1793/2000
# ----------
# Epoch 1794/2000
# ----------
# Epoch 1795/2000
# ----------
# Epoch 1796/2000
# ----------
# Epoch 1797/2000
# ----------
# Epoch 1798/2000
# ----------
# Epoch 1799/2000
# ----------
# Epoch 1800/2000
# ----------
# Epoch 1801/2000
# ----------
# Epoch 1802/2000
# ----------
# Epoch 1803/2000
# ----------
# Epoch 1804/2000
# ----------
# Epoch 1805/2000
# ----------
# Epoch 1806/2000
# ----------
# Epoch 1807/2000
# ----------
# Epoch 1808/2000
# ----------
# Epoch 1809/2000
# ----------
# Epoch 1810/2000
# ----------
# Epoch 1811/2000
# ----------
# Epoch 1812/2000
# ----------
# Epoch 1813/2000
# ----------
# Epoch 1814/2000
# ----------
# Epoch 1815/2000
# ----------
# Epoch 1816/2000
# ----------
# Epoch 1817/2000
# ----------
# Epoch 1818/2000
# ----------
# Epoch 1819/2000
# ----------
# Epoch 1820/2000
# ----------
# Epoch 1821/2000
# ----------
# Epoch 1822/2000
# ----------
# Epoch 1823/2000
# ----------
# Epoch 1824/2000
# ----------
# Epoch 1825/2000
# ----------
# Epoch 1826/2000
# ----------
# Epoch 1827/2000
# ----------
# Epoch 1828/2000
# ----------
# Epoch 1829/2000
# ----------
# Epoch 1830/2000
# ----------
# Epoch 1831/2000
# ----------
# Epoch 1832/2000
# ----------
# Epoch 1833/2000
# ----------
# Epoch 1834/2000
# ----------
# Epoch 1835/2000
# ----------
# Epoch 1836/2000
# ----------
# Epoch 1837/2000
# ----------
# Epoch 1838/2000
# ----------
# Epoch 1839/2000
# ----------
# Epoch 1840/2000
# ----------
# Epoch 1841/2000
# ----------
# Epoch 1842/2000
# ----------
# Epoch 1843/2000
# ----------
# Epoch 1844/2000
# ----------
# Epoch 1845/2000
# ----------
# Epoch 1846/2000
# ----------
# Epoch 1847/2000
# ----------
# Epoch 1848/2000
# ----------
# Epoch 1849/2000
# ----------
# Epoch 1850/2000
# ----------
# Epoch 1851/2000
# ----------
# Epoch 1852/2000
# ----------
# Epoch 1853/2000
# ----------
# Epoch 1854/2000
# ----------
# Epoch 1855/2000
# ----------
# Epoch 1856/2000
# ----------
# Epoch 1857/2000
# ----------
# Epoch 1858/2000
# ----------
# Epoch 1859/2000
# ----------
# Epoch 1860/2000
# ----------
# Epoch 1861/2000
# ----------
# Epoch 1862/2000
# ----------
# Epoch 1863/2000
# ----------
# Epoch 1864/2000
# ----------
# Epoch 1865/2000
# ----------
# Epoch 1866/2000
# ----------
# Epoch 1867/2000
# ----------
# Epoch 1868/2000
# ----------
# Epoch 1869/2000
# ----------
# Epoch 1870/2000
# ----------
# Epoch 1871/2000
# ----------
# Epoch 1872/2000
# ----------
# Epoch 1873/2000
# ----------
# Epoch 1874/2000
# ----------
# Epoch 1875/2000
# ----------
# Epoch 1876/2000
# ----------
# Epoch 1877/2000
# ----------
# Epoch 1878/2000
# ----------
# Epoch 1879/2000
# ----------
# Epoch 1880/2000
# ----------
# Epoch 1881/2000
# ----------
# Epoch 1882/2000
# ----------
# Epoch 1883/2000
# ----------
# Epoch 1884/2000
# ----------
# Epoch 1885/2000
# ----------
# Epoch 1886/2000
# ----------
# Epoch 1887/2000
# ----------
# Epoch 1888/2000
# ----------
# Epoch 1889/2000
# ----------
# Epoch 1890/2000
# ----------
# Epoch 1891/2000
# ----------
# Epoch 1892/2000
# ----------
# Epoch 1893/2000
# ----------
# Epoch 1894/2000
# ----------
# Epoch 1895/2000
# ----------
# Epoch 1896/2000
# ----------
# Epoch 1897/2000
# ----------
# Epoch 1898/2000
# ----------
# Epoch 1899/2000
# ----------
# Epoch 1900/2000
# ----------
# Epoch 1901/2000
# ----------
# Epoch 1902/2000
# ----------
# Epoch 1903/2000
# ----------
# Epoch 1904/2000
# ----------
# Epoch 1905/2000
# ----------
# Epoch 1906/2000
# ----------
# Epoch 1907/2000
# ----------
# Epoch 1908/2000
# ----------
# Epoch 1909/2000
# ----------
# Epoch 1910/2000
# ----------
# Epoch 1911/2000
# ----------
# Epoch 1912/2000
# ----------
# Epoch 1913/2000
# ----------
# Epoch 1914/2000
# ----------
# Epoch 1915/2000
# ----------
# Epoch 1916/2000
# ----------
# Epoch 1917/2000
# ----------
# Epoch 1918/2000
# ----------
# Epoch 1919/2000
# ----------
# Epoch 1920/2000
# ----------
# Epoch 1921/2000
# ----------
# Epoch 1922/2000
# ----------
# Epoch 1923/2000
# ----------
# Epoch 1924/2000
# ----------
# Epoch 1925/2000
# ----------
# Epoch 1926/2000
# ----------
# Epoch 1927/2000
# ----------
# Epoch 1928/2000
# ----------
# Epoch 1929/2000
# ----------
# Epoch 1930/2000
# ----------
# Epoch 1931/2000
# ----------
# Epoch 1932/2000
# ----------
# Epoch 1933/2000
# ----------
# Epoch 1934/2000
# ----------
# Epoch 1935/2000
# ----------
# Epoch 1936/2000
# ----------
# Epoch 1937/2000
# ----------
# Epoch 1938/2000
# ----------
# Epoch 1939/2000
# ----------
# Epoch 1940/2000
# ----------
# Epoch 1941/2000
# ----------
# Epoch 1942/2000
# ----------
# Epoch 1943/2000
# ----------
# Epoch 1944/2000
# ----------
# Epoch 1945/2000
# ----------
# Epoch 1946/2000
# ----------
# Epoch 1947/2000
# ----------
# Epoch 1948/2000
# ----------
# Epoch 1949/2000
# ----------
# Epoch 1950/2000
# ----------
# Epoch 1951/2000
# ----------
# Epoch 1952/2000
# ----------
# Epoch 1953/2000
# ----------
# Epoch 1954/2000
# ----------
# Epoch 1955/2000
# ----------
# Epoch 1956/2000
# ----------
# Epoch 1957/2000
# ----------
# Epoch 1958/2000
# ----------
# Epoch 1959/2000
# ----------
# Epoch 1960/2000
# ----------
# Epoch 1961/2000
# ----------
# Epoch 1962/2000
# ----------
# Epoch 1963/2000
# ----------
# Epoch 1964/2000
# ----------
# Epoch 1965/2000
# ----------
# Epoch 1966/2000
# ----------
# Epoch 1967/2000
# ----------
# Epoch 1968/2000
# ----------
# Epoch 1969/2000
# ----------
# Epoch 1970/2000
# ----------
# Epoch 1971/2000
# ----------
# Epoch 1972/2000
# ----------
# Epoch 1973/2000
# ----------
# Epoch 1974/2000
# ----------
# Epoch 1975/2000
# ----------
# Epoch 1976/2000
# ----------
# Epoch 1977/2000
# ----------
# Epoch 1978/2000
# ----------
# Epoch 1979/2000
# ----------
# Epoch 1980/2000
# ----------
# Epoch 1981/2000
# ----------
# Epoch 1982/2000
# ----------
# Epoch 1983/2000
# ----------
# Epoch 1984/2000
# ----------
# Epoch 1985/2000
# ----------
# Epoch 1986/2000
# ----------
# Epoch 1987/2000
# ----------
# Epoch 1988/2000
# ----------
# Epoch 1989/2000
# ----------
# Epoch 1990/2000
# ----------
# Epoch 1991/2000
# ----------
# Epoch 1992/2000
# ----------
# Epoch 1993/2000
# ----------
# Epoch 1994/2000
# ----------
# Epoch 1995/2000
# ----------
# Epoch 1996/2000
# ----------
# Epoch 1997/2000
# ----------
# Epoch 1998/2000
# ----------
# Epoch 1999/2000
# ----------
# Epoch 2000/2000
# ----------
# Training completed time: 2:58:04.492627
